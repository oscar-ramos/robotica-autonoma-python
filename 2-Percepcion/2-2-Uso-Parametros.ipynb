# %% [markdown]
# # Uso de los Parámetros de Calibración
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/oscar-ramos/robotica-autonoma-python/blob/main/2-Percepcion/2-2-Uso-Parametros.ipynb)

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import pickle

# %% [markdown]
# Cargar los parámetros intrínsecos de la cámara almacenados en un archivo.

# %%
params = pickle.load(open('camera_params.p', 'rb'))
params['M']
params['coefs_dist']

# Visualización de los parámetros
print("Matriz de calibración:"); print(np.round(params['M'],3))
print("\nCoeficientes de distorsión:"); print(np.round(params['coefs_dist'],3))
# Out:
# Matriz de calibración:
# [[174.786   0.    203.069]
#  [  0.    175.149 155.515]
#  [  0.      0.      1.   ]]
#
# Coeficientes de distorsión:
# [[-0.232  0.061 -0.     0.    -0.007]]

# %% [markdown]
# Aplicar los parámetros para quitar la distorsión a una imagen de prueba

# %%
# !wget -q https://github.com/oscar-ramos/robotica-autonoma-python/raw/main/2-Percepcion/imagenes_prueba/imagen1.png

# %%
# Imagen de entrada
Iorig = cv2.imread('imagen1.png')

# Corregir la distorsión
Iundist = cv2.undistort(Iorig, params['M'], params['coefs_dist'], None)

# Visualize undistortion
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,10))
ax1.imshow(Iorig)
ax1.set_title('Imagen original', fontsize=20); ax1.axis('off')
ax2.imshow(Iundist)
ax2.set_title('Imagen sin distorsión', fontsize=20); ax2.axis('off');
